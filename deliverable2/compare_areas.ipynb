# %%
from __future__ import print_function 
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib as mpl 
import datetime as dt

mpl.rcParams['savefig.dpi'] = 100 
mpl.rcParams['figure.dpi'] = 100
mpl.rcParams.update({'font.size': 40})

# %config InlineBackend.figure_format = 'retina' 
# %matplotlib inline

import matplotlib.dates as mdates

# %%
import geojson
from shapely.geometry import mapping, shape

# %%
taxi_zones = geojson.load(open('taxi_zones.geojson'))

# %%
z_hoods = geojson.load(open('ZillowNeighborhoods-NY.geojson'))

# %%
z_hoods['features'][0]['properties']
# Out:
# {u'City': u'Town of Islip',
#  u'County': u'Suffolk',
#  u'Name': u'Bohemia',
#  u'RegionID': u'3736',
#  u'State': u'NY'}

# %%
list(z_hoods['features'][0].keys())
# Out:
# ['geometry', u'type', 'properties']

# %%
len(z_hoods['features'])
# Out:
# 579

# %%
z0 = shape(z_hoods['features'][0]['geometry'])
z0

# %%
class Neighborhood(object):
    def __init__(self, feature):
        self.properties = feature['properties']
        self.geometry = feature['geometry']
        self.shape = shape(feature['geometry'])

z_hoods_shapes = [Neighborhood(f)
                  for f in z_hoods['features']
                  if f['properties']['City'] == 'New York']
taxi_zones_shapes = [Neighborhood(f) for f in taxi_zones['features']]

# %%
print(len(z_hoods_shapes))
print(len(taxi_zones_shapes))
# Out:
# 278
# 263

# %%
def plot(gjs, **kwargs):
    test_lon, test_lat = -73.955, 40.727
    for feature in gjs:
        x, y = feature
        plt.plot(x,y,**kwargs)

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

z_col = '#0055aaff'
t_col = 'orange'

z_patch = mpatches.Patch(facecolor='white', edgecolor=z_col, label='Zillow')
t_patch = mpatches.Patch(facecolor='white', edgecolor=t_col, label='TLC')

def plot(shape, **kwargs):
    if shape.type == 'MultiPolygon':
        for g in shape.geoms:
            plot(g, **kwargs)
    else:
        x, y = shape.exterior.xy
        plt.plot(x ,y, **kwargs)

plt.figure(figsize=(8,8))
plt.title('Zillow Neighborhoods vs. TLC Taxi Zones')
[plot(z.shape, color=z_col, linewidth=1.5) for z in z_hoods_shapes]
[plot(t.shape, color=t_col, linewidth=1.2) for t in taxi_zones_shapes]
test_lon, test_lat = -73.955, 40.727
plt.legend(handles=[z_patch, t_patch], loc='best')
plt.show()

# %%
# Closeup plot.
z_patch = mpatches.Patch(facecolor='white', edgecolor=z_col, label='Zillow')
t_patch = mpatches.Patch(facecolor='white', edgecolor=t_col, label='TLC')

def plot(shape, **kwargs):
    if shape.type == 'MultiPolygon':
        for g in shape.geoms:
            plot(g, **kwargs)
    else:
        x, y = shape.exterior.xy
        plt.plot(x ,y, **kwargs)

plt.figure(figsize=(5, 5))
[plot(z.shape, color=z_col, linewidth=1.5) for z in z_hoods_shapes]
[plot(t.shape, color=t_col, linewidth=1.2) for t in taxi_zones_shapes]
 
plt.xlim(-74.05, -73.92)
plt.ylim(40.7, 40.8)

plt.legend(handles=[z_patch, t_patch], loc='best')
plt.show()

# %%
taxi_zones_shapes[3].shape.intersection(z_hoods_shapes[3].shape).area
# Out:
# 0.0

# %% [markdown]
# # Calculate Neighborhood Adjacency

# %%
# Create an adjacency matrix.
from shapely.affinity import translate
z_edges = {}
for za in z_hoods_shapes:
    ida = int(za.properties['RegionID'])
    print(za.properties['County'], za.properties['Name'])
    cax, cay = za.shape.centroid.xy
    for zb in z_hoods_shapes:
        if za.properties['County'] != zb.properties['County']:
            continue
        idb = int(zb.properties['RegionID'])
        cbx, cby = zb.shape.centroid.xy
        dx = cax[0] - cbx[0]
        dy = cay[0] - cby[0]
        intersect = za.shape.intersection(translate(zb.shape, 0.01 * dx, 0.01 * dy))
        if intersect.area > 0:
            k1 = (ida, idb)
            k2 = (idb, ida)
            if k1 in z_edges or k2 in z_edges:
                pass
            else:
                z_edges[k1] = True
z_edges = list(z_edges.keys())
# Out:
# Queens Rego Park
# Queens Belle Harbor
# New York Roosevelt Island
# Queens Howard Beach
# Queens Breezy Point
# Queens Neponsit
# Queens East Elmhurst
# Bronx West Farms
# Queens Cambria Heights
# Queens Fresh Meadows
# Queens Maspeth
# Kings Fort Hamilton
# Richmond Bay Terrace
# Queens Far Rockaway
# Queens Hollis
# Queens Jamaica
# Queens South Ozone Park
# New York Ellis Island
# Queens Bayside
# Queens La Guardia Airport
# Queens Woodhaven
# Queens Arverne
# Queens Broad Channel
# Queens Flushing
# Queens Oakland Gardens
# Queens Ozone Park
# Queens Fort Tilden
# Queens Malba
# Queens Briarwood
# Queens College Point
# Queens Corona
# Queens Pomonok
# Queens Jamaica Estates
# Queens Rockaway Park
# Queens Roxbury
# Queens Rockaway Beach
# Queens Glen Oaks
# Richmond Arrochar
# Queens Kew Gardens Hills
# Kings Bensonhurst
# Kings Bath Beach
# Kings Bay Ridge
# Bronx Clason Point
# Richmond Clifton
# Kings East Flatbush
# Kings Bergen Beach
# Kings Borough Park
# Kings Brighton Beach
# Kings Brownsville
# Kings Canarsie
# Kings East New York
# Richmond Elm Park
# Kings Dyker Heights
# Richmond Fresh Kills
# Richmond Huguenot
# Kings Coney Island
# Kings Flatbush
# Kings Manhattan Beach
# Richmond Mariner's Harbor
# Richmond New Brighton
# Richmond New Dorp Beach
# Richmond Park Hill
# Kings Park Slope
# Richmond Port Ivory
# Richmond Port Richmond
# Richmond Sunnyside
# Bronx Van Nest
# New York Washington Heights
# Richmond Willowbrook
# Richmond Woodrow
# Queens Woodside
# Richmond Fort Wadsworth
# Richmond Grant City
# Richmond Bulls Head
# Kings Bushwick
# New York Chinatown
# Richmond Dongan Hills
# Bronx East Tremont
# Richmond Graniteville
# New York Greenwich Village
# Richmond Grymes Hill
# Richmond Great Kills
# Richmond Greenridge
# New York Inwood
# Richmond Midland Beach
# New York Harlem
# Queens Middle Village
# Queens Murray Hill
# Richmond Pleasant Plains
# Richmond Rosebank
# Richmond New Dorp
# Kings New Utrecht
# Richmond Oakwood
# Bronx Port Morris
# Richmond New Springville
# Richmond Rossville
# Kings Red Hook
# Richmond Shore Acres
# Richmond South Beach
# Richmond Stapleton
# Richmond Tompkinsville
# Kings Williamsburg
# Queens Auburndale
# Queens Bay Terrace
# Kings Clinton Hill
# Kings Cobble Hill
# Bronx Concourse
# Kings Greenpoint
# New York Hamilton Heights
# Bronx Marble Hill
# New York Marble Hill
# Kings Marine Park
# Bronx North Riverdale
# Kings Prospect Park South
# Richmond Randall Manor
# Richmond Todt Hill
# Queens Astoria Heights
# New York Carnegie Hill
# Bronx Castle Hill
# Bronx Co-op City
# New York East Harlem
# New York Financial District
# Kings Gerritsen Beach
# Bronx Bronx Park
# Kings Kensington
# Kings Crown Heights
# Kings Columbia Street Waterfront District
# Kings Prospect Heights
# Kings Prospect Lefferts Gardens
# Queens East Jamaica Bay Islands
# Queens Flushing Meadows Corona Park
# Queens Hillcrest
# Queens Jacob Riis Park
# Kings Floyd Bennett Field
# Queens Elmhurst
# Queens Floral park

# %%
z_edges[:10]
# Out:
# [(275247, 274285),
#  (4819, 18131),
#  (270902, 403222),
#  (193587, 193587),
#  (49994, 26352),
#  (270828, 270828),
#  (270852, 270852),
#  (49994, 276345),
#  (195511, 197623),
#  (194737, 270914)]

# %%
len(z_edges)
zset = set(z_edges)
plt.figure(figsize=(5, 5))
[plot(z.shape, color=z_col, linewidth=1.5) for z in z_hoods_shapes]
for za in z_hoods_shapes:
    ida = int(za.properties['RegionID'])
    cax, cay = za.shape.centroid.xy
    for zb in z_hoods_shapes:
        idb = int(zb.properties['RegionID'])
        cbx, cby = zb.shape.centroid.xy
        k1 = (ida, idb)
        k2 = (idb, ida)
        if k1 in zset or k2 in zset:
            plt.plot([cax[0], cbx[0]], [cay[0], cby[0]], color='k', linewidth=1.0)
            
plt.xlim(-74.05, -73.92)
plt.ylim(40.7, 40.8)
    
plt.show()

# %%
import json
json.dump(z_edges, open('ZillowNeighborhoods_RegionID_edges.json', 'w'))

# %% [markdown]
# ## For Taxis

# %%
taxi_zones_shapes[3].properties
# Out:
# {u'LocationID': 4,
#  u'OBJECTID': 4,
#  u'Shape_Area': 0.000111871946192,
#  u'Shape_Leng': 0.0435665270921,
#  u'borough': u'Manhattan',
#  u'zone': u'Alphabet City'}

# %%
# Create an adjacency matrix.
t_edges = {}
num_neighbors = []
for za in taxi_zones_shapes:
    ida = int(za.properties['LocationID'])
    cax, cay = za.shape.centroid.xy
    nb = 0
    for zb in taxi_zones_shapes:
        if za.properties['borough'] != zb.properties['borough']:
            continue
        idb = int(zb.properties['LocationID'])
        cbx, cby = zb.shape.centroid.xy
        dx = cax[0] - cbx[0]
        dy = cay[0] - cby[0]
        intersect = za.shape.intersection(translate(zb.shape, 0.01 * dx, 0.01 * dy))
        if intersect.area > 0:
            nb += 1
            k1 = (ida, idb)
            k2 = (idb, ida)
            if k1 in t_edges or k2 in t_edges:
                pass
            else:
                t_edges[k1] = True
        num_neighbors.append(nb)
t_edges = list(t_edges.keys())

# %%
import pandas as pd
pd.DataFrame(num_neighbors).describe()
# Out:
#                   0
# count  15493.000000
# mean       2.973085
# std        2.321302
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max       14.000000

# %%
tset = set(t_edges)
plt.figure(figsize=(8,8))
[plot(z.shape, color=t_col, linewidth=1.5) for z in taxi_zones_shapes]
for za in taxi_zones_shapes:
    ida = int(za.properties['LocationID'])
    cax, cay = za.shape.centroid.xy
    for zb in taxi_zones_shapes:
        idb = int(zb.properties['LocationID'])
        cbx, cby = zb.shape.centroid.xy
        k1 = (ida, idb)
        k2 = (idb, ida)
        if k1 in tset or k2 in tset:
            plt.plot([cax[0], cbx[0]], [cay[0], cby[0]], color='k', linewidth=1)
    
plt.show()

# %%
print(len(t_edges))
json.dump(t_edges, open('taxi_zones_LocationID_edges.json', 'w'))
# Out:
# 895
